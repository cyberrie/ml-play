# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
# read the data
data=pd.read_csv("car_data.csv")
print('CSV file loaded')
# Out:
# CSV file loaded

# %%
# LG model predicting MPG based on the Horsepower
X=data[['Horsepower']] #independent 
y=data['MPG'] # dependant

# create an LG model
model=LinearRegression()
model.fit(X,y) # train the model

#predict scores
y_pred=model.predict(X)

# plot the data points and the regression line
plt.scatter(X, y, color='blue') # data points
plt.plot(X, y_pred, color='pink') # regression line

plt.title('Horsepower vs. MPG')
plt.xlabel('Horsepower')
plt.ylabel('MPG')

# find the R
r_squared=r2_score(y, y_pred)
print(f'R-squared = {r_squared:.2f}')


plt.show()
# Out:
# R-squared = 0.12

# %%
# LG model predicting MPG based on the Horsepower
X=data[['Engine Size (L)']]
y=data['MPG'] 

# create an LG model
model=LinearRegression()
model.fit(X,y) 

#predict scores
y_pred=model.predict(X)

# plot the data points and the regression line
plt.scatter(X, y, color='blue') 
plt.plot(X, y_pred, color='pink') 

plt.title('Engine Size (L) vs. MPG')
plt.xlabel('Engine Size (L)')
plt.ylabel('MPG')

# find the R
r_squared=r2_score(y, y_pred)
print(f'R-squared = {r_squared:.2f}')


plt.show()
# Out:
# R-squared = 0.70
